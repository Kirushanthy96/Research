# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline

# %%
# %store -r ODI_2019 
# %store -r ODI_2020
# %store -r ODI_2021

# %%
 ODI_2019
# Out:
#           Team 1       Team 2       Winner     Margin           Ground  \
# 0    New Zealand    Sri Lanka  New Zealand    45 runs  Mount Maunganui
# 1    New Zealand    Sri Lanka  New Zealand    21 runs  Mount Maunganui
# 2    New Zealand    Sri Lanka  New Zealand   115 runs           Nelson
# 3      Australia        India    Australia    34 runs           Sydney
# 4      Australia        India        India  6 wickets         Adelaide
# ..           ...          ...          ...        ...              ...
# 140  Afghanistan  West Indies  West Indies    47 runs          Lucknow
# 141  Afghanistan  West Indies  West Indies  5 wickets          Lucknow
# 147        India  West Indies  West Indies  8 wickets          Chennai
# 148        India  West Indies        India   107 runs    Visakhapatnam
# 149        India  West Indies        India  4 wickets          Cuttack
#
#        Match Date   Scorecard
# 0     Jan 3, 2019  ODI # 4074
# 1     Jan 5, 2019  ODI # 4075
# ...

# %%
ODI_2020
# Out:
#           Team 1       Team 2        Winner      Margin           Ground  \
# 2    West Indies      Ireland   West Indies   5 wickets       Bridgetown
# 5    West Indies      Ireland   West Indies    1 wicket       Bridgetown
# 6    West Indies      Ireland   West Indies   5 wickets      St George's
# 7          India    Australia     Australia  10 wickets         Wankhede
# 8          India    Australia         India     36 runs           Rajkot
# 9          India    Australia         India   7 wickets        Bengaluru
# 10  South Africa      England  South Africa   7 wickets        Cape Town
# 11   New Zealand        India   New Zealand   4 wickets         Hamilton
# 14  South Africa      England     no result         NaN           Durban
# 15   New Zealand        India   New Zealand     22 runs         Auckland
# 18  South Africa      England       England   2 wickets     Johannesburg
# 19   New Zealand        India   New Zealand   5 wickets  Mount Maunganui
# ...

# %%
ODI_2021
# Out:
#           Team 1        Team 2        Winner     Margin             Ground  \
# 2     Bangladesh   West Indies    Bangladesh  6 wickets             Mirpur
# 3    Afghanistan       Ireland   Afghanistan    16 runs          Abu Dhabi
# 4     Bangladesh   West Indies    Bangladesh  7 wickets             Mirpur
# 5    Afghanistan       Ireland   Afghanistan  7 wickets          Abu Dhabi
# 6     Bangladesh   West Indies    Bangladesh   120 runs         Chattogram
# 7    Afghanistan       Ireland   Afghanistan    36 runs          Abu Dhabi
# 8    West Indies     Sri Lanka   West Indies  8 wickets        North Sound
# 9    West Indies     Sri Lanka   West Indies  5 wickets        North Sound
# 10   West Indies     Sri Lanka   West Indies  5 wickets        North Sound
# 11   New Zealand    Bangladesh   New Zealand  8 wickets            Dunedin
# 12   New Zealand    Bangladesh   New Zealand  5 wickets       Christchurch
# ...

# %%
ODI_2019_filter =ODI_2019.drop(['Margin','Ground','Scorecard'],axis = 1)

# %%
ODI_2019_filter
# Out:
#           Team 1       Team 2       Winner    Match Date
# 0    New Zealand    Sri Lanka  New Zealand   Jan 3, 2019
# 1    New Zealand    Sri Lanka  New Zealand   Jan 5, 2019
# 2    New Zealand    Sri Lanka  New Zealand   Jan 8, 2019
# 3      Australia        India    Australia  Jan 12, 2019
# 4      Australia        India        India  Jan 15, 2019
# ..           ...          ...          ...           ...
# 140  Afghanistan  West Indies  West Indies   Nov 9, 2019
# 141  Afghanistan  West Indies  West Indies  Nov 11, 2019
# 147        India  West Indies  West Indies  Dec 15, 2019
# 148        India  West Indies        India  Dec 18, 2019
# 149        India  West Indies        India  Dec 22, 2019
#
# [119 rows x 4 columns]

# %%
ODI_2019_filter = ODI_2019_filter.reset_index(drop=True)
ODI_2019_filter.loc[ODI_2019_filter.Winner == ODI_2019_filter['Team 1'],'Result']=1
ODI_2019_filter.loc[ODI_2019_filter.Winner == ODI_2019_filter['Team 2'], 'Result']=0
ODI_2019_filter.drop(['Winner'],axis=1, inplace=True)

ODI_2019_filter.head()
# Out:
#         Team 1     Team 2    Match Date  Result
# 0  New Zealand  Sri Lanka   Jan 3, 2019     1.0
# 1  New Zealand  Sri Lanka   Jan 5, 2019     1.0
# 2  New Zealand  Sri Lanka   Jan 8, 2019     1.0
# 3    Australia      India  Jan 12, 2019     1.0
# 4    Australia      India  Jan 15, 2019     0.0

# %%
ODI_2019_filter['Result'] = ODI_2019_filter['Result'].fillna(0).astype(int)

# %%
ODI_2019_filter
# Out:
#           Team 1       Team 2    Match Date  Result
# 0    New Zealand    Sri Lanka   Jan 3, 2019       1
# 1    New Zealand    Sri Lanka   Jan 5, 2019       1
# 2    New Zealand    Sri Lanka   Jan 8, 2019       1
# 3      Australia        India  Jan 12, 2019       1
# 4      Australia        India  Jan 15, 2019       0
# ..           ...          ...           ...     ...
# 114  Afghanistan  West Indies   Nov 9, 2019       0
# 115  Afghanistan  West Indies  Nov 11, 2019       0
# 116        India  West Indies  Dec 15, 2019       0
# 117        India  West Indies  Dec 18, 2019       1
# 118        India  West Indies  Dec 22, 2019       1
#
# [119 rows x 4 columns]

# %%
ODI_2019_filter['Match Date'] = pd.to_datetime(ODI_2019_filter['Match Date']).dt.year

# %%
ODI_2019_filter
# Out:
#           Team 1       Team 2  Match Date  Result
# 0    New Zealand    Sri Lanka        2019       1
# 1    New Zealand    Sri Lanka        2019       1
# 2    New Zealand    Sri Lanka        2019       1
# 3      Australia        India        2019       1
# 4      Australia        India        2019       0
# ..           ...          ...         ...     ...
# 114  Afghanistan  West Indies        2019       0
# 115  Afghanistan  West Indies        2019       0
# 116        India  West Indies        2019       0
# 117        India  West Indies        2019       1
# 118        India  West Indies        2019       1
#
# [119 rows x 4 columns]

# %%
# %store -r SL_Ave_2018
# %store -r India_Ave_2018
# %store -r pakistan_Ave_2018
# %store -r Bankaladesh_Ave_2018
# %store -r Newzeleand_Ave_2018
# %store -r England_Ave_2018
# %store -r WestIndies_Ave_2018
# %store -r SouthAfrica_Ave_2018
# %store -r Ireland_Ave_2018
# %store -r Scotland_Ave_2018
# %store -r Australia_Ave_2018
# %store -r Afhanistan_Ave_2018

# %%
# %store -r SL_Ave_2019
# %store -r India_Ave_2019
# %store -r pakistan_Ave_2019
# %store -r Bankaladesh_Ave_2019
# %store -r Newzeleand_Ave_2019
# %store -r England_Ave_2019
# %store -r WestIndies_Ave_2019
# %store -r SouthAfrica_Ave_2019
# %store -r Ireland_Ave_2019
# %store -r Scotland_Ave_2019
# %store -r Australia_Ave_2019
# %store -r Afhanistan_Ave_2019

# %%
# %store -r SL_Ave_2020
# %store -r India_Ave_2020
# %store -r pakistan_Ave_2020
# %store -r Bankaladesh_Ave_2020
# %store -r Newzeleand_Ave_2020
# %store -r England_Ave_2020
# %store -r WestIndies_Ave_2020
# %store -r SouthAfrica_Ave_2020
# %store -r Ireland_Ave_2020
# %store -r Scotland_Ave_2020
# %store -r Australia_Ave_2020
# %store -r Afhanistan_Ave_2020

# %%
{'England':England_Ave_2018, 'South Africa':SouthAfrica_Ave_2018, 'Scotland':Scotland_Ave_2018, 'West Indies':WestIndies_Ave_2018, 
            'Pakistan':pakistan_Ave_2018, 'New Zealand': Newzeleand_Ave_2018, 'Sri Lanka':SL_Ave_2018, 'Afghanistan':Afhanistan_Ave_2018, 
            'Australia':Australia_Ave_2018, 'Bangladesh':Bankaladesh_Ave_2018, 'India':India_Ave_2018,'Ireland':Ireland_Ave_2018}
# Out:
# {'England': array([2.11471052e-17, 7.40148683e-17]),
#  'South Africa': array([-3.41607085e-17, -1.15292391e-16]),
#  'Scotland': array([-2.61228947e-17,  1.63268092e-16]),
#  'West Indies': array([ 1.24344979e-16, -4.44089210e-18]),
#  'Pakistan': array([1.00929366e-16, 1.27423324e-16]),
#  'New Zealand': array([-1.59186390e-16, -1.17553026e-16]),
#  'Sri Lanka': array([4.91060184e-17, 7.68615940e-17]),
#  'Afghanistan': array([1.81141651e-16, 8.18059071e-17]),
#  'Australia': array([ 8.8817842e-18, -8.8817842e-17]),
#  'Bangladesh': array([-1.77635684e-17, -5.32907052e-17]),
#  'India': array([1.0658141e-16, 0.0000000e+00]),
#  'Ireland': array([-4.07081776e-17,  1.48029737e-16])}

# %%
dict_map= {'England':England_Ave_2018, 'South Africa':SouthAfrica_Ave_2018, 'Scotland':Scotland_Ave_2018, 'West Indies':WestIndies_Ave_2018, 
            'Pakistan':pakistan_Ave_2018, 'New Zealand': Newzeleand_Ave_2018, 'Sri Lanka':SL_Ave_2018, 'Afghanistan':Afhanistan_Ave_2018, 
            'Australia':Australia_Ave_2018, 'Bangladesh':Bankaladesh_Ave_2018, 'India':India_Ave_2018,'Ireland':Ireland_Ave_2018}

# %%
ODI_2019_filter['Team 1']=ODI_2019_filter['Team 1'].map(dict_map)

# %%
ODI_2019_filter['Team 2']=ODI_2019_filter['Team 2'].map(dict_map)

# %%
ODI_2019_filter
# Out:
#                                                 Team 1  \
# 0    [-1.5918638956022465e-16, -1.1755302613678128e...
# 1    [-1.5918638956022465e-16, -1.1755302613678128e...
# 2    [-1.5918638956022465e-16, -1.1755302613678128e...
# 3      [8.881784197001253e-18, -8.881784197001253e-17]
# 4      [8.881784197001253e-18, -8.881784197001253e-17]
# ..                                                 ...
# 114    [1.8114165138620975e-16, 8.180590707764311e-17]
# 115    [1.8114165138620975e-16, 8.180590707764311e-17]
# 116                      [1.0658141036401502e-16, 0.0]
# 117                      [1.0658141036401502e-16, 0.0]
# 118                      [1.0658141036401502e-16, 0.0]
#
#                                                Team 2  Match Date  Result
# 0      [4.910601839688192e-17, 7.686159401251084e-17]        2019       1
# 1      [4.910601839688192e-17, 7.686159401251084e-17]        2019       1
# 2      [4.910601839688192e-17, 7.686159401251084e-17]        2019       1
# ...

# %%
ODI_2019_filter[['Team 1_Batting','Team 1_bowling']] = pd.DataFrame(ODI_2019_filter['Team 1'].tolist(), index= ODI_2019_filter.index)
ODI_2019_filter[['Team 2_Batting','Team 2_bowling']] = pd.DataFrame(ODI_2019_filter['Team 2'].tolist(), index= ODI_2019_filter.index)
ODI_2019_filter
# Out:
#                                                 Team 1  \
# 0    [-1.5918638956022465e-16, -1.1755302613678128e...
# 1    [-1.5918638956022465e-16, -1.1755302613678128e...
# 2    [-1.5918638956022465e-16, -1.1755302613678128e...
# 3      [8.881784197001253e-18, -8.881784197001253e-17]
# 4      [8.881784197001253e-18, -8.881784197001253e-17]
# ..                                                 ...
# 114    [1.8114165138620975e-16, 8.180590707764311e-17]
# 115    [1.8114165138620975e-16, 8.180590707764311e-17]
# 116                      [1.0658141036401502e-16, 0.0]
# 117                      [1.0658141036401502e-16, 0.0]
# 118                      [1.0658141036401502e-16, 0.0]
#
#                                                Team 2  Match Date  Result  \
# 0      [4.910601839688192e-17, 7.686159401251084e-17]        2019       1
# 1      [4.910601839688192e-17, 7.686159401251084e-17]        2019       1
# 2      [4.910601839688192e-17, 7.686159401251084e-17]        2019       1
# ...

# %%
ODI_2019_filter.drop(['Team 1','Team 2','Match Date'],inplace=True,axis=1)

# %%
ODI_2019_filter
# Out:
#      Result  Team 1_Batting  Team 1_bowling  Team 2_Batting  Team 2_bowling
# 0         1   -1.591864e-16   -1.175530e-16    4.910602e-17    7.686159e-17
# 1         1   -1.591864e-16   -1.175530e-16    4.910602e-17    7.686159e-17
# 2         1   -1.591864e-16   -1.175530e-16    4.910602e-17    7.686159e-17
# 3         1    8.881784e-18   -8.881784e-17    1.065814e-16    0.000000e+00
# 4         0    8.881784e-18   -8.881784e-17    1.065814e-16    0.000000e+00
# ..      ...             ...             ...             ...             ...
# 114       0    1.811417e-16    8.180591e-17    1.243450e-16   -4.440892e-18
# 115       0    1.811417e-16    8.180591e-17    1.243450e-16   -4.440892e-18
# 116       0    1.065814e-16    0.000000e+00    1.243450e-16   -4.440892e-18
# 117       1    1.065814e-16    0.000000e+00    1.243450e-16   -4.440892e-18
# 118       1    1.065814e-16    0.000000e+00    1.243450e-16   -4.440892e-18
#
# [119 rows x 5 columns]

# %% [markdown]
# # 2020 matches

# %%
ODI_2020_filter =ODI_2020.drop(['Margin','Ground','Scorecard'],axis = 1)

# %%
ODI_2020_filter
# Out:
#           Team 1       Team 2        Winner    Match Date
# 2    West Indies      Ireland   West Indies   Jan 7, 2020
# 5    West Indies      Ireland   West Indies   Jan 9, 2020
# 6    West Indies      Ireland   West Indies  Jan 12, 2020
# 7          India    Australia     Australia  Jan 14, 2020
# 8          India    Australia         India  Jan 17, 2020
# 9          India    Australia         India  Jan 19, 2020
# 10  South Africa      England  South Africa   Feb 4, 2020
# 11   New Zealand        India   New Zealand   Feb 5, 2020
# 14  South Africa      England     no result   Feb 7, 2020
# 15   New Zealand        India   New Zealand   Feb 8, 2020
# 18  South Africa      England       England   Feb 9, 2020
# 19   New Zealand        India   New Zealand  Feb 11, 2020
# 22     Sri Lanka  West Indies     Sri Lanka  Feb 22, 2020
# 23     Sri Lanka  West Indies     Sri Lanka  Feb 26, 2020
# 24  South Africa    Australia  South Africa  Feb 29, 2020
# ...

# %%
ODI_2020_filter = ODI_2020_filter.reset_index(drop=True)
ODI_2020_filter.loc[ODI_2020_filter.Winner == ODI_2020_filter['Team 1'],'Result']=1
ODI_2020_filter.loc[ODI_2020_filter.Winner == ODI_2020_filter['Team 2'], 'Result']=0
ODI_2020_filter.drop(['Winner'],axis=1, inplace=True)

ODI_2020_filter.head()
# Out:
#         Team 1     Team 2    Match Date  Result
# 0  West Indies    Ireland   Jan 7, 2020     1.0
# 1  West Indies    Ireland   Jan 9, 2020     1.0
# 2  West Indies    Ireland  Jan 12, 2020     1.0
# 3        India  Australia  Jan 14, 2020     0.0
# 4        India  Australia  Jan 17, 2020     1.0

# %%
ODI_2020_filter['Result'] = ODI_2020_filter['Result'].fillna(0).astype(int)

# %%
ODI_2020_filter
# Out:
#           Team 1       Team 2    Match Date  Result
# 0    West Indies      Ireland   Jan 7, 2020       1
# 1    West Indies      Ireland   Jan 9, 2020       1
# 2    West Indies      Ireland  Jan 12, 2020       1
# 3          India    Australia  Jan 14, 2020       0
# 4          India    Australia  Jan 17, 2020       1
# 5          India    Australia  Jan 19, 2020       1
# 6   South Africa      England   Feb 4, 2020       1
# 7    New Zealand        India   Feb 5, 2020       1
# 8   South Africa      England   Feb 7, 2020       0
# 9    New Zealand        India   Feb 8, 2020       1
# 10  South Africa      England   Feb 9, 2020       0
# 11   New Zealand        India  Feb 11, 2020       1
# 12     Sri Lanka  West Indies  Feb 22, 2020       1
# 13     Sri Lanka  West Indies  Feb 26, 2020       1
# 14  South Africa    Australia  Feb 29, 2020       1
# 15     Sri Lanka  West Indies   Mar 1, 2020       1
# 16  South Africa    Australia   Mar 4, 2020       1
# ...

# %%
ODI_2020_filter['Match Date'] = pd.to_datetime(ODI_2020_filter['Match Date']).dt.year

# %%
ODI_2020_filter
# Out:
#           Team 1       Team 2  Match Date  Result
# 0    West Indies      Ireland        2020       1
# 1    West Indies      Ireland        2020       1
# 2    West Indies      Ireland        2020       1
# 3          India    Australia        2020       0
# 4          India    Australia        2020       1
# 5          India    Australia        2020       1
# 6   South Africa      England        2020       1
# 7    New Zealand        India        2020       1
# 8   South Africa      England        2020       0
# 9    New Zealand        India        2020       1
# 10  South Africa      England        2020       0
# 11   New Zealand        India        2020       1
# 12     Sri Lanka  West Indies        2020       1
# 13     Sri Lanka  West Indies        2020       1
# 14  South Africa    Australia        2020       1
# 15     Sri Lanka  West Indies        2020       1
# 16  South Africa    Australia        2020       1
# 17  South Africa    Australia        2020       1
# ...

# %%
{'England':England_Ave_2019, 'South Africa':SouthAfrica_Ave_2019, 'Scotland':Scotland_Ave_2019, 'West Indies':WestIndies_Ave_2019, 
            'Pakistan':pakistan_Ave_2019, 'New Zealand': Newzeleand_Ave_2019, 'Sri Lanka':SL_Ave_2019, 'Afghanistan':Afhanistan_Ave_2019, 
            'Australia':Australia_Ave_2019, 'Bangladesh':Bankaladesh_Ave_2019, 'India':India_Ave_2019,'Ireland':Ireland_Ave_2019}
# Out:
# {'England': array([-4.67462326e-17, -4.67462326e-17]),
#  'South Africa': array([5.00954292e-17, 4.60336376e-17]),
#  'Scotland': array([-1.63611814e-16, -8.18059071e-17]),
#  'West Indies': array([ 1.11022302e-16, -3.51570624e-17]),
#  'Pakistan': array([3.96508223e-17, 2.77555756e-16]),
#  'New Zealand': array([ 1.04491579e-16, -2.61228947e-17]),
#  'Sri Lanka': array([-2.46716228e-17,  2.77555756e-17]),
#  'Afghanistan': array([1.11022302e-16, 5.95588393e-17]),
#  'Australia': array([ 1.88737914e-16, -5.41233725e-17]),
#  'Bangladesh': array([-1.07167361e-16, -2.71387850e-16]),
#  'India': array([ 7.99360578e-17, -6.21724894e-17]),
#  'Ireland': array([-1.51113689e-16, -2.46716228e-17])}

# %%
dict_map= {'England':England_Ave_2019, 'South Africa':SouthAfrica_Ave_2019, 'Scotland':Scotland_Ave_2019, 'West Indies':WestIndies_Ave_2019, 
            'Pakistan':pakistan_Ave_2019, 'New Zealand': Newzeleand_Ave_2019, 'Sri Lanka':SL_Ave_2019, 'Afghanistan':Afhanistan_Ave_2019, 
            'Australia':Australia_Ave_2019, 'Bangladesh':Bankaladesh_Ave_2019, 'India':India_Ave_2019,'Ireland':Ireland_Ave_2019}

# %%
ODI_2020_filter['Team 1']=ODI_2020_filter['Team 1'].map(dict_map)

# %%
ODI_2020_filter['Team 2']=ODI_2020_filter['Team 2'].map(dict_map)

# %%
ODI_2020_filter
# Out:
#                                                Team 1  \
# 0    [1.1102230246251565e-16, -3.515706244646329e-17]
# 1    [1.1102230246251565e-16, -3.515706244646329e-17]
# 2    [1.1102230246251565e-16, -3.515706244646329e-17]
# 3     [7.993605777301127e-17, -6.217248937900877e-17]
# 4     [7.993605777301127e-17, -6.217248937900877e-17]
# 5     [7.993605777301127e-17, -6.217248937900877e-17]
# 6       [5.00954291599156e-17, 4.603363760640893e-17]
# 7   [1.0449157878825003e-16, -2.6122894697062506e-17]
# 8       [5.00954291599156e-17, 4.603363760640893e-17]
# 9   [1.0449157878825003e-16, -2.6122894697062506e-17]
# 10      [5.00954291599156e-17, 4.603363760640893e-17]
# 11  [1.0449157878825003e-16, -2.6122894697062506e-17]
# 12  [-2.4671622769447922e-17, 2.7755575615628914e-17]
# 13  [-2.4671622769447922e-17, 2.7755575615628914e-17]
# 14      [5.00954291599156e-17, 4.603363760640893e-17]
# 15  [-2.4671622769447922e-17, 2.7755575615628914e-17]
# ...

# %%
ODI_2020_filter[['Team 1_Batting','Team 1_bowling']] = pd.DataFrame(ODI_2020_filter['Team 1'].tolist(), index= ODI_2020_filter.index)
ODI_2020_filter[['Team 2_Batting','Team 2_bowling']] = pd.DataFrame(ODI_2020_filter['Team 2'].tolist(), index= ODI_2020_filter.index)
ODI_2020_filter
# Out:
#                                                Team 1  \
# 0    [1.1102230246251565e-16, -3.515706244646329e-17]
# 1    [1.1102230246251565e-16, -3.515706244646329e-17]
# 2    [1.1102230246251565e-16, -3.515706244646329e-17]
# 3     [7.993605777301127e-17, -6.217248937900877e-17]
# 4     [7.993605777301127e-17, -6.217248937900877e-17]
# 5     [7.993605777301127e-17, -6.217248937900877e-17]
# 6       [5.00954291599156e-17, 4.603363760640893e-17]
# 7   [1.0449157878825003e-16, -2.6122894697062506e-17]
# 8       [5.00954291599156e-17, 4.603363760640893e-17]
# 9   [1.0449157878825003e-16, -2.6122894697062506e-17]
# 10      [5.00954291599156e-17, 4.603363760640893e-17]
# 11  [1.0449157878825003e-16, -2.6122894697062506e-17]
# 12  [-2.4671622769447922e-17, 2.7755575615628914e-17]
# 13  [-2.4671622769447922e-17, 2.7755575615628914e-17]
# 14      [5.00954291599156e-17, 4.603363760640893e-17]
# 15  [-2.4671622769447922e-17, 2.7755575615628914e-17]
# ...

# %%
ODI_2020_filter.drop(['Team 1','Team 2','Match Date'],inplace=True,axis=1)

# %%
ODI_2020_filter
# Out:
#     Result  Team 1_Batting  Team 1_bowling  Team 2_Batting  Team 2_bowling
# 0        1    1.110223e-16   -3.515706e-17   -1.511137e-16   -2.467162e-17
# 1        1    1.110223e-16   -3.515706e-17   -1.511137e-16   -2.467162e-17
# 2        1    1.110223e-16   -3.515706e-17   -1.511137e-16   -2.467162e-17
# 3        0    7.993606e-17   -6.217249e-17    1.887379e-16   -5.412337e-17
# 4        1    7.993606e-17   -6.217249e-17    1.887379e-16   -5.412337e-17
# 5        1    7.993606e-17   -6.217249e-17    1.887379e-16   -5.412337e-17
# 6        1    5.009543e-17    4.603364e-17   -4.674623e-17   -4.674623e-17
# 7        1    1.044916e-16   -2.612289e-17    7.993606e-17   -6.217249e-17
# 8        0    5.009543e-17    4.603364e-17   -4.674623e-17   -4.674623e-17
# 9        1    1.044916e-16   -2.612289e-17    7.993606e-17   -6.217249e-17
# 10       0    5.009543e-17    4.603364e-17   -4.674623e-17   -4.674623e-17
# ...

# %% [markdown]
# # 2021 mateches

# %%
ODI_2021_filter =ODI_2021.drop(['Margin','Ground','Scorecard'],axis = 1)

# %%
ODI_2021_filter
# Out:
#           Team 1        Team 2        Winner       Match Date
# 2     Bangladesh   West Indies    Bangladesh     Jan 20, 2021
# 3    Afghanistan       Ireland   Afghanistan     Jan 21, 2021
# 4     Bangladesh   West Indies    Bangladesh     Jan 22, 2021
# 5    Afghanistan       Ireland   Afghanistan     Jan 24, 2021
# 6     Bangladesh   West Indies    Bangladesh     Jan 25, 2021
# 7    Afghanistan       Ireland   Afghanistan     Jan 26, 2021
# 8    West Indies     Sri Lanka   West Indies     Mar 10, 2021
# 9    West Indies     Sri Lanka   West Indies     Mar 12, 2021
# 10   West Indies     Sri Lanka   West Indies     Mar 14, 2021
# 11   New Zealand    Bangladesh   New Zealand     Mar 20, 2021
# 12   New Zealand    Bangladesh   New Zealand     Mar 23, 2021
# 13         India       England         India     Mar 23, 2021
# 14   New Zealand    Bangladesh   New Zealand     Mar 26, 2021
# 15         India       England       England     Mar 26, 2021
# ...

# %%
ODI_2021_filter = ODI_2021_filter.reset_index(drop=True)
ODI_2021_filter.loc[ODI_2021_filter.Winner == ODI_2021_filter['Team 1'],'Result']=1
ODI_2021_filter.loc[ODI_2021_filter.Winner == ODI_2021_filter['Team 2'], 'Result']=0
ODI_2021_filter.drop(['Winner'],axis=1, inplace=True)

ODI_2021_filter.head()
# Out:
#         Team 1       Team 2    Match Date  Result
# 0   Bangladesh  West Indies  Jan 20, 2021     1.0
# 1  Afghanistan      Ireland  Jan 21, 2021     1.0
# 2   Bangladesh  West Indies  Jan 22, 2021     1.0
# 3  Afghanistan      Ireland  Jan 24, 2021     1.0
# 4   Bangladesh  West Indies  Jan 25, 2021     1.0

# %%
ODI_2021_filter['Result'] = ODI_2021_filter['Result'].fillna(0).astype(int)

# %%
ODI_2021_filter
# Out:
#           Team 1        Team 2       Match Date  Result
# 0     Bangladesh   West Indies     Jan 20, 2021       1
# 1    Afghanistan       Ireland     Jan 21, 2021       1
# 2     Bangladesh   West Indies     Jan 22, 2021       1
# 3    Afghanistan       Ireland     Jan 24, 2021       1
# 4     Bangladesh   West Indies     Jan 25, 2021       1
# 5    Afghanistan       Ireland     Jan 26, 2021       1
# 6    West Indies     Sri Lanka     Mar 10, 2021       1
# 7    West Indies     Sri Lanka     Mar 12, 2021       1
# 8    West Indies     Sri Lanka     Mar 14, 2021       1
# 9    New Zealand    Bangladesh     Mar 20, 2021       1
# 10   New Zealand    Bangladesh     Mar 23, 2021       1
# 11         India       England     Mar 23, 2021       1
# 12   New Zealand    Bangladesh     Mar 26, 2021       1
# 13         India       England     Mar 26, 2021       0
# 14         India       England     Mar 28, 2021       1
# 15  South Africa      Pakistan      Apr 2, 2021       0
# ...

# %%
ODI_2021_filter['Match Date'] = pd.to_datetime(ODI_2021_filter['Match Date']).dt.year

# %%
ODI_2021_filter
# Out:
#           Team 1        Team 2  Match Date  Result
# 0     Bangladesh   West Indies        2021       1
# 1    Afghanistan       Ireland        2021       1
# 2     Bangladesh   West Indies        2021       1
# 3    Afghanistan       Ireland        2021       1
# 4     Bangladesh   West Indies        2021       1
# 5    Afghanistan       Ireland        2021       1
# 6    West Indies     Sri Lanka        2021       1
# 7    West Indies     Sri Lanka        2021       1
# 8    West Indies     Sri Lanka        2021       1
# 9    New Zealand    Bangladesh        2021       1
# 10   New Zealand    Bangladesh        2021       1
# 11         India       England        2021       1
# 12   New Zealand    Bangladesh        2021       1
# 13         India       England        2021       0
# 14         India       England        2021       1
# 15  South Africa      Pakistan        2021       0
# 16  South Africa      Pakistan        2021       1
# ...

# %%
{'England':England_Ave_2020, 'South Africa':SouthAfrica_Ave_2020, 'Scotland':Scotland_Ave_2020, 'West Indies':WestIndies_Ave_2020, 
            'Pakistan':pakistan_Ave_2020, 'New Zealand': Newzeleand_Ave_2020, 'Sri Lanka':SL_Ave_2020, 'Afghanistan':Afhanistan_Ave_2020, 
             'Australia':Australia_Ave_2020,'Bangladesh':Bankaladesh_Ave_2020,'India':India_Ave_2020,'Ireland':Ireland_Ave_2020}
# Out:
# {'England': array([-4.22942105e-17, -8.19450328e-17]),
#  'South Africa': array([ 3.95306683e-17, -9.42007415e-17]),
#  'Scotland': array([0., 0.]),
#  'West Indies': array([-1.40238698e-16, -1.89906570e-17]),
#  'Pakistan': array([2.42861287e-17, 6.85215773e-17]),
#  'New Zealand': array([ 8.23993651e-17, -9.71445147e-17]),
#  'Sri Lanka': array([2.72509288e-16, 1.00929366e-16]),
#  'Afghanistan': array([0., 0.]),
#  'Australia': array([-1.16573418e-16, -1.11022302e-17]),
#  'Bangladesh': array([ 2.96059473e-17, -2.22044605e-17]),
#  'India': array([ 1.49880108e-16, -3.33066907e-17]),
#  'Ireland': array([ 2.42861287e-17, -5.20417043e-17])}

# %%
dict_map= {'England':England_Ave_2020, 'South Africa':SouthAfrica_Ave_2020, 'Scotland':Scotland_Ave_2020, 'West Indies':WestIndies_Ave_2020, 
            'Pakistan':pakistan_Ave_2020, 'New Zealand': Newzeleand_Ave_2020, 'Sri Lanka':SL_Ave_2020, 'Afghanistan':Afhanistan_Ave_2020, 
             'Australia':Australia_Ave_2020,'Bangladesh':Bankaladesh_Ave_2020,'India':India_Ave_2020,'Ireland':Ireland_Ave_2020}

# %%
ODI_2021_filter['Team 1']=ODI_2021_filter['Team 1'].map(dict_map)

# %%
ODI_2021_filter['Team 2']=ODI_2021_filter['Team 2'].map(dict_map)

# %%
ODI_2021_filter
# Out:
#                                                Team 1  \
# 0    [2.960594732333751e-17, -2.2204460492503132e-17]
# 1                                          [0.0, 0.0]
# 2    [2.960594732333751e-17, -2.2204460492503132e-17]
# 3                                          [0.0, 0.0]
# 4    [2.960594732333751e-17, -2.2204460492503132e-17]
# 5                                          [0.0, 0.0]
# 6   [-1.4023869784738819e-16, -1.8990657000167152e...
# 7   [-1.4023869784738819e-16, -1.8990657000167152e...
# 8   [-1.4023869784738819e-16, -1.8990657000167152e...
# 9      [8.239936510889834e-17, -9.71445146547012e-17]
# 10     [8.239936510889834e-17, -9.71445146547012e-17]
# 11  [1.4988010832439614e-16, -3.3306690738754695e-17]
# 12     [8.239936510889834e-17, -9.71445146547012e-17]
# 13  [1.4988010832439614e-16, -3.3306690738754695e-17]
# 14  [1.4988010832439614e-16, -3.3306690738754695e-17]
# 15    [3.953066830104724e-17, -9.420074148334662e-17]
# ...

# %%
ODI_2021_filter[['Team 1_Batting','Team 1_bowling']] = pd.DataFrame(ODI_2021_filter['Team 1'].tolist(), index= ODI_2021_filter.index)
ODI_2021_filter[['Team 2_Batting','Team 2_bowling']] = pd.DataFrame(ODI_2021_filter['Team 2'].tolist(), index= ODI_2021_filter.index)
ODI_2021_filter
# Out:
#                                                Team 1  \
# 0    [2.960594732333751e-17, -2.2204460492503132e-17]
# 1                                          [0.0, 0.0]
# 2    [2.960594732333751e-17, -2.2204460492503132e-17]
# 3                                          [0.0, 0.0]
# 4    [2.960594732333751e-17, -2.2204460492503132e-17]
# 5                                          [0.0, 0.0]
# 6   [-1.4023869784738819e-16, -1.8990657000167152e...
# 7   [-1.4023869784738819e-16, -1.8990657000167152e...
# 8   [-1.4023869784738819e-16, -1.8990657000167152e...
# 9      [8.239936510889834e-17, -9.71445146547012e-17]
# 10     [8.239936510889834e-17, -9.71445146547012e-17]
# 11  [1.4988010832439614e-16, -3.3306690738754695e-17]
# 12     [8.239936510889834e-17, -9.71445146547012e-17]
# 13  [1.4988010832439614e-16, -3.3306690738754695e-17]
# 14  [1.4988010832439614e-16, -3.3306690738754695e-17]
# 15    [3.953066830104724e-17, -9.420074148334662e-17]
# ...

# %%
ODI_2021_filter.drop(['Team 1','Team 2','Match Date'],inplace=True,axis=1)

# %%
ODI_2021_filter
# Out:
#     Result  Team 1_Batting  Team 1_bowling  Team 2_Batting  Team 2_bowling
# 0        1    2.960595e-17   -2.220446e-17   -1.402387e-16   -1.899066e-17
# 1        1    0.000000e+00    0.000000e+00    2.428613e-17   -5.204170e-17
# 2        1    2.960595e-17   -2.220446e-17   -1.402387e-16   -1.899066e-17
# 3        1    0.000000e+00    0.000000e+00    2.428613e-17   -5.204170e-17
# 4        1    2.960595e-17   -2.220446e-17   -1.402387e-16   -1.899066e-17
# 5        1    0.000000e+00    0.000000e+00    2.428613e-17   -5.204170e-17
# 6        1   -1.402387e-16   -1.899066e-17    2.725093e-16    1.009294e-16
# 7        1   -1.402387e-16   -1.899066e-17    2.725093e-16    1.009294e-16
# 8        1   -1.402387e-16   -1.899066e-17    2.725093e-16    1.009294e-16
# 9        1    8.239937e-17   -9.714451e-17    2.960595e-17   -2.220446e-17
# 10       1    8.239937e-17   -9.714451e-17    2.960595e-17   -2.220446e-17
# ...

# %%
ODI_matches = pd.concat([ODI_2019_filter,ODI_2020_filter,ODI_2021_filter])

# %%
ODI_matches
# Out:
#     Result  Team 1_Batting  Team 1_bowling  Team 2_Batting  Team 2_bowling
# 0        1   -1.591864e-16   -1.175530e-16    4.910602e-17    7.686159e-17
# 1        1   -1.591864e-16   -1.175530e-16    4.910602e-17    7.686159e-17
# 2        1   -1.591864e-16   -1.175530e-16    4.910602e-17    7.686159e-17
# 3        1    8.881784e-18   -8.881784e-17    1.065814e-16    0.000000e+00
# 4        0    8.881784e-18   -8.881784e-17    1.065814e-16    0.000000e+00
# ..     ...             ...             ...             ...             ...
# 34       1    2.725093e-16    1.009294e-16    1.498801e-16   -3.330669e-17
# 35       0   -1.402387e-16   -1.899066e-17   -1.165734e-16   -1.110223e-17
# 36       1    2.725093e-16    1.009294e-16    3.953067e-17   -9.420074e-17
# 37       0    2.725093e-16    1.009294e-16    3.953067e-17   -9.420074e-17
# 38       1    2.725093e-16    1.009294e-16    3.953067e-17   -9.420074e-17
#
# [186 rows x 5 columns]

# %%
Players_batAndBall = ODI_matches

# %%
# %store Players_batAndBall
# Out:
# Stored 'Players_batAndBall' (DataFrame)

# %% [markdown]
# # Apply Random Forest

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import confusion_matrix

# %%
import sklearn.metrics as metrics

# %%
X =ODI_matches.drop(['Result'],axis=1)

# %%
y=ODI_matches['Result']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((130, 4), (56, 4))

# %%
pip install -U scikit-learn==0.21.3
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'K:\4th' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier(n_estimators=200)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
rfc_predict =rfc.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, rfc_predict))
# Out:
# Accuracy: 0.7142857142857143

# %%
print(confusion_matrix(y_test,rfc_predict))
print('\n')
print(classification_report(y_test,rfc_predict))
# Out:
# [[ 0 16]
#  [ 0 40]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        16
#            1       0.71      1.00      0.83        40
#
#     accuracy                           0.71        56
#    macro avg       0.36      0.50      0.42        56
# weighted avg       0.51      0.71      0.60        56
# K:\4th year\my research practical\jupyter\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# K:\4th year\my research practical\jupyter\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# # Apply SVM

# %%
 from sklearn.svm import SVC

# %%
model =SVC()

# %%
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
predictions=model.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, predictions))
# Out:
# Accuracy: 0.75

# %%
print(confusion_matrix(y_test,predictions))
print('\n')
print(classification_report(y_test,predictions))
# Out:
# [[ 8  8]
#  [ 6 34]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.50      0.53        16
#            1       0.81      0.85      0.83        40
#
#     accuracy                           0.75        56
#    macro avg       0.69      0.68      0.68        56
# weighted avg       0.74      0.75      0.74        56
