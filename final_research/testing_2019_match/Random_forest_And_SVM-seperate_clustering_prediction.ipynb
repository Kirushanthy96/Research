# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline

# %%
# %store -r ODI_2019

# %%
 ODI_2019
# Out:
#           Team 1       Team 2       Winner     Margin           Ground  \
# 0    New Zealand    Sri Lanka  New Zealand    45 runs  Mount Maunganui
# 1    New Zealand    Sri Lanka  New Zealand    21 runs  Mount Maunganui
# 2    New Zealand    Sri Lanka  New Zealand   115 runs           Nelson
# 3      Australia        India    Australia    34 runs           Sydney
# 4      Australia        India        India  6 wickets         Adelaide
# ..           ...          ...          ...        ...              ...
# 140  Afghanistan  West Indies  West Indies    47 runs          Lucknow
# 141  Afghanistan  West Indies  West Indies  5 wickets          Lucknow
# 147        India  West Indies  West Indies  8 wickets          Chennai
# 148        India  West Indies        India   107 runs    Visakhapatnam
# 149        India  West Indies        India  4 wickets          Cuttack
#
#        Match Date   Scorecard
# 0     Jan 3, 2019  ODI # 4074
# 1     Jan 5, 2019  ODI # 4075
# ...

# %%
ODI_2019_filter =ODI_2019.drop(['Margin','Ground','Scorecard'],axis = 1)

# %%
ODI_2019_filter
# Out:
#           Team 1       Team 2       Winner    Match Date
# 0    New Zealand    Sri Lanka  New Zealand   Jan 3, 2019
# 1    New Zealand    Sri Lanka  New Zealand   Jan 5, 2019
# 2    New Zealand    Sri Lanka  New Zealand   Jan 8, 2019
# 3      Australia        India    Australia  Jan 12, 2019
# 4      Australia        India        India  Jan 15, 2019
# ..           ...          ...          ...           ...
# 140  Afghanistan  West Indies  West Indies   Nov 9, 2019
# 141  Afghanistan  West Indies  West Indies  Nov 11, 2019
# 147        India  West Indies  West Indies  Dec 15, 2019
# 148        India  West Indies        India  Dec 18, 2019
# 149        India  West Indies        India  Dec 22, 2019
#
# [119 rows x 4 columns]

# %%
ODI_2019_filter = ODI_2019_filter.reset_index(drop=True)
ODI_2019_filter.loc[ODI_2019_filter.Winner == ODI_2019_filter['Team 1'],'Result']=1
ODI_2019_filter.loc[ODI_2019_filter.Winner == ODI_2019_filter['Team 2'], 'Result']=0
ODI_2019_filter.drop(['Winner'],axis=1, inplace=True)

ODI_2019_filter.head()
# Out:
#         Team 1     Team 2    Match Date  Result
# 0  New Zealand  Sri Lanka   Jan 3, 2019     1.0
# 1  New Zealand  Sri Lanka   Jan 5, 2019     1.0
# 2  New Zealand  Sri Lanka   Jan 8, 2019     1.0
# 3    Australia      India  Jan 12, 2019     1.0
# 4    Australia      India  Jan 15, 2019     0.0

# %%
ODI_2019_filter['Result'] = ODI_2019_filter['Result'].fillna(0).astype(int)

# %%
ODI_2019_filter
# Out:
#           Team 1       Team 2    Match Date  Result
# 0    New Zealand    Sri Lanka   Jan 3, 2019       1
# 1    New Zealand    Sri Lanka   Jan 5, 2019       1
# 2    New Zealand    Sri Lanka   Jan 8, 2019       1
# 3      Australia        India  Jan 12, 2019       1
# 4      Australia        India  Jan 15, 2019       0
# ..           ...          ...           ...     ...
# 114  Afghanistan  West Indies   Nov 9, 2019       0
# 115  Afghanistan  West Indies  Nov 11, 2019       0
# 116        India  West Indies  Dec 15, 2019       0
# 117        India  West Indies  Dec 18, 2019       1
# 118        India  West Indies  Dec 22, 2019       1
#
# [119 rows x 4 columns]

# %%
ODI_2019_filter['Match Date'] = pd.to_datetime(ODI_2019_filter['Match Date']).dt.year

# %%
ODI_2019_filter
# Out:
#           Team 1       Team 2  Match Date  Result
# 0    New Zealand    Sri Lanka        2019       1
# 1    New Zealand    Sri Lanka        2019       1
# 2    New Zealand    Sri Lanka        2019       1
# 3      Australia        India        2019       1
# 4      Australia        India        2019       0
# ..           ...          ...         ...     ...
# 114  Afghanistan  West Indies        2019       0
# 115  Afghanistan  West Indies        2019       0
# 116        India  West Indies        2019       0
# 117        India  West Indies        2019       1
# 118        India  West Indies        2019       1
#
# [119 rows x 4 columns]

# %%
# %store -r SL_Cluster_2018
# %store -r India_Cluster_2018
# %store -r pakistan_Cluster_2018
# %store -r Bankaladesh_Cluster_2018
# %store -r Newzeleand_Cluster_2018
# %store -r England_Cluster_2018
# %store -r WestIndies_Cluster_2018
# %store -r SouthAfrica_Cluster_2018
# %store -r Ireland_Cluster_2018
# %store -r Scotland_Cluster_2018
# %store -r Australia_Cluster_2018
# %store -r Afhanistan_Cluster_2018

# %%
{'England':England_Cluster_2018, 'South Africa':SouthAfrica_Cluster_2018, 'Scotland':Scotland_Cluster_2018, 'West Indies':WestIndies_Cluster_2018, 
            'Pakistan':pakistan_Cluster_2018, 'New Zealand': Newzeleand_Cluster_2018, 'Sri Lanka':SL_Cluster_2018, 'Afghanistan':Afhanistan_Cluster_2018, 
            'Australia':Australia_Cluster_2018, 'Bangladesh':Bankaladesh_Cluster_2018, 'India':India_Cluster_2018,'Ireland':Ireland_Cluster_2018}
# Out:
# {'England': array([7, 6, 8]),
#  'South Africa': array([ 4, 14,  8]),
#  'Scotland': array([6, 5, 6]),
#  'West Indies': array([14,  6,  5]),
#  'Pakistan': array([ 6, 13,  3]),
#  'New Zealand': array([7, 5, 5]),
#  'Sri Lanka': array([16,  2,  8]),
#  'Afghanistan': array([4, 9, 6]),
#  'Australia': array([13,  8,  4]),
#  'Bangladesh': array([ 7, 13,  5]),
#  'India': array([15,  5,  5]),
#  'Ireland': array([5, 6, 4])}

# %%
dict_map={'England':England_Cluster_2018, 'South Africa':SouthAfrica_Cluster_2018, 'Scotland':Scotland_Cluster_2018, 'West Indies':WestIndies_Cluster_2018, 
            'Pakistan':pakistan_Cluster_2018, 'New Zealand': Newzeleand_Cluster_2018, 'Sri Lanka':SL_Cluster_2018, 'Afghanistan':Afhanistan_Cluster_2018, 
            'Australia':Australia_Cluster_2018, 'Bangladesh':Bankaladesh_Cluster_2018, 'India':India_Cluster_2018,'Ireland':Ireland_Cluster_2018}

# %%
ODI_2019_filter['Team 1']=ODI_2019_filter['Team 1'].map(dict_map)

# %%
ODI_2019_filter['Team 2']=ODI_2019_filter['Team 2'].map(dict_map)

# %%
ODI_2019_filter
# Out:
#          Team 1      Team 2  Match Date  Result
# 0     [7, 5, 5]  [16, 2, 8]        2019       1
# 1     [7, 5, 5]  [16, 2, 8]        2019       1
# 2     [7, 5, 5]  [16, 2, 8]        2019       1
# 3    [13, 8, 4]  [15, 5, 5]        2019       1
# 4    [13, 8, 4]  [15, 5, 5]        2019       0
# ..          ...         ...         ...     ...
# 114   [4, 9, 6]  [14, 6, 5]        2019       0
# 115   [4, 9, 6]  [14, 6, 5]        2019       0
# 116  [15, 5, 5]  [14, 6, 5]        2019       0
# 117  [15, 5, 5]  [14, 6, 5]        2019       1
# 118  [15, 5, 5]  [14, 6, 5]        2019       1
#
# [119 rows x 4 columns]

# %%
ODI_2019_filter[['Team 1_Cluster1','Team 1_Cluster2','Team 1_Cluster3']] = pd.DataFrame(ODI_2019_filter['Team 1'].tolist(), index= ODI_2019_filter.index)
ODI_2019_filter[['Team 2_Cluster1','Team 2_Cluster2','Team 2_Cluster3']] = pd.DataFrame(ODI_2019_filter['Team 2'].tolist(), index= ODI_2019_filter.index)
ODI_2019_filter
# Out:
#          Team 1      Team 2  Match Date  Result  Team 1_Cluster1  \
# 0     [7, 5, 5]  [16, 2, 8]        2019       1                7
# 1     [7, 5, 5]  [16, 2, 8]        2019       1                7
# 2     [7, 5, 5]  [16, 2, 8]        2019       1                7
# 3    [13, 8, 4]  [15, 5, 5]        2019       1               13
# 4    [13, 8, 4]  [15, 5, 5]        2019       0               13
# ..          ...         ...         ...     ...              ...
# 114   [4, 9, 6]  [14, 6, 5]        2019       0                4
# 115   [4, 9, 6]  [14, 6, 5]        2019       0                4
# 116  [15, 5, 5]  [14, 6, 5]        2019       0               15
# 117  [15, 5, 5]  [14, 6, 5]        2019       1               15
# 118  [15, 5, 5]  [14, 6, 5]        2019       1               15
#
#      Team 1_Cluster2  Team 1_Cluster3  Team 2_Cluster1  Team 2_Cluster2  \
# 0                  5                5               16                2
# ...

# %%
ODI_2019_filter.drop(['Team 1','Team 2','Match Date'],inplace=True,axis=1)

# %%
ODI_2019_filter
# Out:
#      Result  Team 1_Cluster1  Team 1_Cluster2  Team 1_Cluster3  \
# 0         1                7                5                5
# 1         1                7                5                5
# 2         1                7                5                5
# 3         1               13                8                4
# 4         0               13                8                4
# ..      ...              ...              ...              ...
# 114       0                4                9                6
# 115       0                4                9                6
# 116       0               15                5                5
# 117       1               15                5                5
# 118       1               15                5                5
#
#      Team 2_Cluster1  Team 2_Cluster2  Team 2_Cluster3
# 0                 16                2                8
# 1                 16                2                8
# ...

# %%
Team_Clustering=ODI_2019_filter

# %%
# %store Team_Clustering
# Out:
# Stored 'Team_Clustering' (DataFrame)

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import confusion_matrix

# %%
import sklearn.metrics as metrics

# %%
X =ODI_2019_filter.drop(['Result'],axis=1)

# %%
y=ODI_2019_filter['Result']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((83, 6), (36, 6))

# %%
pip install -U scikit-learn==0.21.3
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'K:\4th' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier(n_estimators=200)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
rfc_predict =rfc.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, rfc_predict))
# Out:
# Accuracy: 0.6666666666666666

# %%
print(confusion_matrix(y_test,rfc_predict))
print('\n')
print(classification_report(y_test,rfc_predict))
# Out:
# [[10  8]
#  [ 4 14]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.56      0.63        18
#            1       0.64      0.78      0.70        18
#
#     accuracy                           0.67        36
#    macro avg       0.68      0.67      0.66        36
# weighted avg       0.68      0.67      0.66        36

# %%
 from sklearn.svm import SVC

# %%
model =SVC()

# %%
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
predictions=model.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, predictions))
# Out:
# Accuracy: 0.5

# %%
print(confusion_matrix(y_test,predictions))
print('\n')
print(classification_report(y_test,predictions))
# Out:
# [[ 4 14]
#  [ 4 14]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.22      0.31        18
#            1       0.50      0.78      0.61        18
#
#     accuracy                           0.50        36
#    macro avg       0.50      0.50      0.46        36
# weighted avg       0.50      0.50      0.46        36
